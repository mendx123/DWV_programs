# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\Admin\Desktop\CMRIT\DW&DV\Third_Program\Child Labour in India.csv')

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df=pd.read_csv('Child Labour in India.csv')

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.shape
# Out:
# (25, 9)

# %%
df.columns
# Out:
# Index(['Category of States', 'States', 'Agriculture', 'Manufacturing',
#        'Construction', 'Trade Hotels & Restaurants',
#        'Community, Social and Personal Services', 'Others', 'Total'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Category of States                          object
# States                                      object
# Agriculture                                float64
# Manufacturing                               object
# Construction                               float64
# Trade Hotels & Restaurants                 float64
# Community, Social and Personal Services    float64
# Others                                     float64
# Total                                        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Category of States                       25 non-null     object
#  1   States                                   25 non-null     object
#  2   Agriculture                              24 non-null     float64
#  3   Manufacturing                            24 non-null     object
#  4   Construction                             22 non-null     float64
#  5   Trade Hotels & Restaurants               25 non-null     float64
#  6   Community, Social and Personal Services  23 non-null     float64
#  7   Others                                   19 non-null     float64
#  8   Total                                    25 non-null     int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.9+ KB

# %%
df.describe()
# Out:
#        Agriculture  Construction  Trade Hotels & Restaurants  \
# count    24.000000     22.000000                   25.000000
# mean     68.500000      2.540909                   11.720000
# std      16.613536      2.046753                   11.186748
# min      19.200000      0.000000                    3.300000
# 25%      65.525000      0.975000                    7.200000
# 50%      70.550000      1.950000                    8.500000
# 75%      80.700000      3.825000                    9.700000
# max      87.900000      7.000000                   57.800000
#
#        Community, Social and Personal Services     Others  Total
# count                                23.000000  19.000000   25.0
# mean                                  5.795652   1.436842  100.0
# std                                   7.119658   0.916643    0.0
# min                                   0.300000   0.000000  100.0
# 25%                                   1.400000   0.900000  100.0
# ...

# %%
df.head()
# Out:
#             Category of States          States  Agriculture Manufacturing  \
# 0  Non Special Category states  Andhra Pradesh         69.0           9.7
# 1  Non Special Category states           Assam         69.3           8.4
# 2  Non Special Category states           Bihar         71.8          11.2
# 3  Non Special Category states    Chhattisgarh         87.9           2.4
# 4  Non Special Category states           Delhi          NaN          11.1
#
#    Construction  Trade Hotels & Restaurants  \
# 0           3.2                         9.0
# 1           1.8                         7.8
# 2           0.0                        15.5
# 3           0.9                         7.2
# 4           NaN                        57.8
#
#    Community, Social and Personal Services  Others  Total
# 0                                      7.1     2.0    100
# 1                                     11.0     1.8    100
# 2                                      1.1     0.5    100
# ...

# %%
df.tail()
# Out:
#               Category of States          States  Agriculture Manufacturing  \
# 20       Special Category States     Uttarakhand         80.7           4.7
# 21       Special Category States     Uttarakhand         80.7           4.7
# 22                     All India       All India         68.1          16.6
# 23   Non Special Category states  Andhra Pradesh         69.0           9.7
# 24  Non Special Category states*    Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 20           5.2                         9.3
# 21           5.2                         9.3
# 22           2.0                         8.5
# 23           4.0                         8.0
# 24           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 20                                      NaN     NaN    100
# 21                                      NaN     NaN    100
# ...

# %%
df.head(1)
# Out:
#             Category of States          States  Agriculture Manufacturing  \
# 0  Non Special Category states  Andhra Pradesh         69.0           9.7
#
#    Construction  Trade Hotels & Restaurants  \
# 0           3.2                         9.0
#
#    Community, Social and Personal Services  Others  Total
# 0                                      7.1     2.0    100

# %%
df.tail(1)
# Out:
#               Category of States        States  Agriculture Manufacturing  \
# 24  Non Special Category states*  Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 24           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 24                                      1.1     0.5    100

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %%
duplicated=df[df.duplicated()]

# %%
duplicated
# Out:
#              Category of States         States  Agriculture Manufacturing  \
# 17  Non Special Category states  Uttar Pradesh         61.2          25.3
# 21      Special Category States    Uttarakhand         80.7           4.7
#
#     Construction  Trade Hotels & Restaurants  \
# 17           0.4                         9.7
# 21           5.2                         9.3
#
#     Community, Social and Personal Services  Others  Total
# 17                                      2.1     1.2    100
# 21                                      NaN     NaN    100

# %%
non_duplicates=df.drop_duplicates()

# %%
non_duplicates
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df['States'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# Name: States, dtype: bool

# %%
df['States'].duplicated().sum()
# Out:
# 3

# %%
duplicated=df[df['States'].duplicated()]

# %%
duplicated
# Out:
#              Category of States          States  Agriculture Manufacturing  \
# 17  Non Special Category states   Uttar Pradesh         61.2          25.3
# 21      Special Category States     Uttarakhand         80.7           4.7
# 23  Non Special Category states  Andhra Pradesh         69.0           9.7
#
#     Construction  Trade Hotels & Restaurants  \
# 17           0.4                         9.7
# 21           5.2                         9.3
# 23           4.0                         8.0
#
#     Community, Social and Personal Services  Others  Total
# 17                                      2.1     1.2    100
# 21                                      NaN     NaN    100
# 23                                      7.1     2.0    100

# %%
non_duplicated_states=df['States'].drop_duplicates()

# %%
non_duplicated_states
# Out:
# 0       Andhra Pradesh
# 1                Assam
# 2                Bihar
# 3         Chhattisgarh
# 4                Delhi
# 5              Gujarat
# 6              Haryana
# 7            Jharkhand
# 8            Karnataka
# 9               Kerala
# 10      Madhya Pradesh
# 11         Maharashtra
# 12              Orissa
# 13              Punjab
# 14           Rajasthan
# 15          Tamil Nadu
# 16       Uttar Pradesh
# 18         West Bengal
# 19    Himachal Pradesh
# 20         Uttarakhand
# 22           All India
# 24        Biha      r*
# Name: States, dtype: object

# %%
df.drop_duplicates(subset=['States'])
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.drop_duplicates(subset=['States'],inplace=True)

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.isnull()
# Out:
#     Category of States  States  Agriculture  Manufacturing  Construction  \
# 0                False   False        False          False         False
# 1                False   False        False          False         False
# 2                False   False        False          False         False
# 3                False   False        False          False         False
# 4                False   False         True          False          True
# 5                False   False        False          False         False
# 6                False   False        False          False         False
# 7                False   False        False          False         False
# 8                False   False        False          False         False
# 9                False   False        False          False          True
# 10               False   False        False          False         False
# 11               False   False        False          False         False
# ...

# %%
df.isnull().sum()
# Out:
# Category of States                         0
# States                                     0
# Agriculture                                1
# Manufacturing                              1
# Construction                               3
# Trade Hotels & Restaurants                 0
# Community, Social and Personal Services    1
# Others                                     5
# Total                                      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 11

# %%
df2=df.fillna(1)

# %%
df2
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          1.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df2.isnull().sum()
# Out:
# Category of States                         0
# States                                     0
# Agriculture                                0
# Manufacturing                              0
# Construction                               0
# Trade Hotels & Restaurants                 0
# Community, Social and Personal Services    0
# Others                                     0
# Total                                      0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.fillna({'Agriculture':0,'Construction':1})
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.isnull().sum()
# Out:
# Category of States                         0
# States                                     0
# Agriculture                                1
# Manufacturing                              1
# Construction                               3
# Trade Hotels & Restaurants                 0
# Community, Social and Personal Services    1
# Others                                     5
# Total                                      0
# dtype: int64

# %%
df.fillna({'Agriculture':0,'Construction':1},inplace=True)

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.isnull().sum()
# Out:
# Category of States                         0
# States                                     0
# Agriculture                                0
# Manufacturing                              1
# Construction                               0
# Trade Hotels & Restaurants                 0
# Community, Social and Personal Services    1
# Others                                     5
# Total                                      0
# dtype: int64

# %%
df.dropna(how='any')
# Out:
#               Category of States          States  Agriculture Manufacturing  \
# 0    Non Special Category states  Andhra Pradesh         69.0           9.7
# 1    Non Special Category states           Assam         69.3           8.4
# 2    Non Special Category states           Bihar         71.8          11.2
# 5    Non Special Category states         Gujarat         76.7           2.6
# 7    Non Special Category states       Jharkhand         65.3          14.6
# 8    Non Special Category states       Karnataka         82.6           9.3
# 10   Non Special Category states  Madhya Pradesh         82.9          9. 9
# 11   Non Special Category states     Maharashtra         82.6           5.3
# 12   Non Special Category states          Orissa         73.2          17.4
# 13   Non Special Category states          Punjab         67.9          12.7
# 14   Non Special Category states       Rajasthan         75.8           9.6
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.dropna(how='any',inplace=True)

# %%
df
# Out:
#               Category of States          States  Agriculture Manufacturing  \
# 0    Non Special Category states  Andhra Pradesh         69.0           9.7
# 1    Non Special Category states           Assam         69.3           8.4
# 2    Non Special Category states           Bihar         71.8          11.2
# 5    Non Special Category states         Gujarat         76.7           2.6
# 7    Non Special Category states       Jharkhand         65.3          14.6
# 8    Non Special Category states       Karnataka         82.6           9.3
# 10   Non Special Category states  Madhya Pradesh         82.9          9. 9
# 11   Non Special Category states     Maharashtra         82.6           5.3
# 12   Non Special Category states          Orissa         73.2          17.4
# 13   Non Special Category states          Punjab         67.9          12.7
# 14   Non Special Category states       Rajasthan         75.8           9.6
# ...

# %%
df.isnull().sum()
# Out:
# Category of States                         0
# States                                     0
# Agriculture                                0
# Manufacturing                              0
# Construction                               0
# Trade Hotels & Restaurants                 0
# Community, Social and Personal Services    0
# Others                                     0
# Total                                      0
# dtype: int64

# %%
sp=pd.read_csv('Child Labour in India special.csv')

# %%
sp['States']
# Out:
# 0       Andhra Pradesh
# 1                Assam
# 2                Bihar
# 3         Chhattisgarh
# 4                Delhi
# 5              Gujarat
# 6              Haryana
# 7            Jharkhand
# 8            Karnataka
# 9               Kerala
# 10      Madhya Pradesh
# 11         Maharashtra
# 12              Orissa
# 13              Punjab
# 14           Rajasthan
# 15          Tamil Nadu
# 16       Uttar Pradesh
# 17       Uttar Pradesh
# 18         West Bengal
# 19    Himachal Pradesh
# 20         Uttarakhand
# 21                  \n
# 22                 NaN
# 23                 NaN
# 24         Uttarakhand
# 25                 NaN
# 26           All India
# 27      Andhra Pradesh
# 28        Biha      r*
# 29                  ""
# 30                 " "
# 31                "\n"
# Name: States, dtype: object

# %%
states=sp['States'].replace(r'\W','',regex=True)

# %%
states
# Out:
# 0       AndhraPradesh
# 1               Assam
# 2               Bihar
# 3        Chhattisgarh
# 4               Delhi
# 5             Gujarat
# 6             Haryana
# 7           Jharkhand
# 8           Karnataka
# 9              Kerala
# 10      MadhyaPradesh
# 11        Maharashtra
# 12             Orissa
# 13             Punjab
# 14          Rajasthan
# 15          TamilNadu
# 16       UttarPradesh
# 17       UttarPradesh
# 18         WestBengal
# 19    HimachalPradesh
# 20        Uttarakhand
# 21                  n
# 22                NaN
# 23                NaN
# 24        Uttarakhand
# 25                NaN
# 26           AllIndia
# 27      AndhraPradesh
# 28              Bihar
# 29
# 30
# 31                  n
# Name: States, dtype: object

# %%
import csv

# %%
# Open the input CSV file in read mode
with open('Child Labour in India.csv','r',newline='') as infile:
    reader=csv.reader(infile)
    # Filter out empty lines
    cleaned_data = [row for row in reader if all(field.strip() for field in row)]

# %%
with open('output.csv', 'w', newline='') as outfile:
    writer = csv.writer(outfile)
    writer.writerows(cleaned_data)

# %%
df3=pd.read_csv('output.csv')

# %%
df3['States']
# Out:
# 0     Andhra Pradesh
# 1              Assam
# 2              Bihar
# 3            Gujarat
# 4          Jharkhand
# 5          Karnataka
# 6     Madhya Pradesh
# 7        Maharashtra
# 8             Orissa
# 9             Punjab
# 10         Rajasthan
# 11        Tamil Nadu
# 12     Uttar Pradesh
# 13     Uttar Pradesh
# 14       West Bengal
# 15         All India
# 16    Andhra Pradesh
# 17      Biha      r*
# Name: States, dtype: object

# %%
cleaned_states=df3['States'].replace(r'\W','',regex=True)

# %%
cleaned_states
# Out:
# 0     AndhraPradesh
# 1             Assam
# 2             Bihar
# 3           Gujarat
# 4         Jharkhand
# 5         Karnataka
# 6     MadhyaPradesh
# 7       Maharashtra
# 8            Orissa
# 9            Punjab
# 10        Rajasthan
# 11        TamilNadu
# 12     UttarPradesh
# 13     UttarPradesh
# 14       WestBengal
# 15         AllIndia
# 16    AndhraPradesh
# 17            Bihar
# Name: States, dtype: object

# %%
print('The total no of rows {}''\n''The total no of columns {}'.format(df.shape[0],df.shape[1]))
# Out:
# The total no of rows 16
# The total no of columns 9

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.drop('States',axis=1)
# Out:
#               Category of States  Agriculture Manufacturing  Construction  \
# 0    Non Special Category states         69.0           9.7           3.2
# 1    Non Special Category states         69.3           8.4           1.8
# 2    Non Special Category states         71.8          11.2           0.0
# 3    Non Special Category states         87.9           2.4           0.9
# 4    Non Special Category states          NaN          11.1           NaN
# 5    Non Special Category states         76.7           2.6           0.3
# 6    Non Special Category states         65.6           3.8           7.0
# 7    Non Special Category states         65.3          14.6           4.3
# 8    Non Special Category states         82.6           9.3           1.2
# 9    Non Special Category states         19.2          32.8           NaN
# 10   Non Special Category states         82.9          9. 9           1.5
# 11   Non Special Category states         82.6           5.3           1.9
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.drop('States',axis=1,inplace=True)

# %%
df
# Out:
#               Category of States  Agriculture Manufacturing  Construction  \
# 0    Non Special Category states         69.0           9.7           3.2
# 1    Non Special Category states         69.3           8.4           1.8
# 2    Non Special Category states         71.8          11.2           0.0
# 3    Non Special Category states         87.9           2.4           0.9
# 4    Non Special Category states          NaN          11.1           NaN
# 5    Non Special Category states         76.7           2.6           0.3
# 6    Non Special Category states         65.6           3.8           7.0
# 7    Non Special Category states         65.3          14.6           4.3
# 8    Non Special Category states         82.6           9.3           1.2
# 9    Non Special Category states         19.2          32.8           NaN
# 10   Non Special Category states         82.9          9. 9           1.5
# 11   Non Special Category states         82.6           5.3           1.9
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.drop(0,axis=0)
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# 11   Non Special Category states       Maharashtra         82.6           5.3
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.drop(0,axis=0,inplace=True)

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# 11   Non Special Category states       Maharashtra         82.6           5.3
# ...

# %%
rename_col=['Category' if 'Category of States' in colname else
            'Agri' if 'Agriculture' in colname else colname for colname in df
           ]

# %%
rename_col
# Out:
# ['Category',
#  'States',
#  'Agri',
#  'Manufacturing',
#  'Construction',
#  'Trade Hotels & Restaurants',
#  'Community, Social and Personal Services',
#  'Others',
#  'Total']

# %%
states_match=df['States']=='Andhra Pradesh'

# %%
states_match
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# Name: States, dtype: bool

# %%
states_match=df[df['States']=='Andhra Pradesh']
states_match
# Out:
#              Category of States          States  Agriculture Manufacturing  \
# 0   Non Special Category states  Andhra Pradesh         69.0           9.7
# 23  Non Special Category states  Andhra Pradesh         69.0           9.7
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 23           4.0                         8.0
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0    100
# 23                                      7.1     2.0    100

# %%
states_non_match=df[df['States']!='Andhra Pradesh']
states_non_match
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# 11   Non Special Category states       Maharashtra         82.6           5.3
# ...

# %%
df['States'].value_counts()
# Out:
# Andhra Pradesh      2
# Uttarakhand         2
# Uttar Pradesh       2
# Assam               1
# All India           1
# Himachal Pradesh    1
# West Bengal         1
# Tamil Nadu          1
# Rajasthan           1
# Punjab              1
# Orissa              1
# Maharashtra         1
# Madhya Pradesh      1
# Kerala              1
# Karnataka           1
# Jharkhand           1
# Haryana             1
# Gujarat             1
# Delhi               1
# Chhattisgarh        1
# Bihar               1
# Biha      r*        1
# Name: States, dtype: int64

# %%
df['States'].value_counts().plot()
# Out:
# <Axes: >

# %%
df['States'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='States'>

# %%
df['States'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi',
#        'Gujarat', 'Haryana', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Orissa', 'Punjab', 'Rajasthan',
#        'Tamil Nadu', 'Uttar Pradesh', 'West Bengal', 'Himachal Pradesh',
#        'Uttarakhand', 'All India', 'Biha      r*'], dtype=object)

# %%
df['States'].nunique()
# Out:
# 22

# %%
df.dtypes
# Out:
# Category of States                          object
# States                                      object
# Agriculture                                float64
# Manufacturing                               object
# Construction                               float64
# Trade Hotels & Restaurants                 float64
# Community, Social and Personal Services    float64
# Others                                     float64
# Total                                        int64
# dtype: object

# %%
df['Manufacturing'] =df['Manufacturing'].replace('9. 9', '9.9')
df['Manufacturing'] = df['Manufacturing'].astype('float')

# %%
df.dtypes
# Out:
# Category of States                          object
# States                                      object
# Agriculture                                float64
# Manufacturing                              float64
# Construction                               float64
# Trade Hotels & Restaurants                 float64
# Community, Social and Personal Services    float64
# Others                                     float64
# Total                                        int64
# dtype: object
