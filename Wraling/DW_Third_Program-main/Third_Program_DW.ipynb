# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\Admin\Desktop\CMRIT\DW&DV\Third_Program\Child Labour in India.csv')
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df=pd.read_csv('Child Labour in India.csv')
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.shape
# Out:
# (25, 9)

# %%
df.columns
# Out:
# Index(['Category of States', 'States', 'Agriculture', 'Manufacturing',
#        'Construction', 'Trade Hotels & Restaurants',
#        'Community, Social and Personal Services', 'Others', 'Total'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Category of States                          object
# States                                      object
# Agriculture                                float64
# Manufacturing                               object
# Construction                               float64
# Trade Hotels & Restaurants                 float64
# Community, Social and Personal Services    float64
# Others                                     float64
# Total                                        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Category of States                       25 non-null     object
#  1   States                                   25 non-null     object
#  2   Agriculture                              24 non-null     float64
#  3   Manufacturing                            24 non-null     object
#  4   Construction                             22 non-null     float64
#  5   Trade Hotels & Restaurants               25 non-null     float64
#  6   Community, Social and Personal Services  23 non-null     float64
#  7   Others                                   19 non-null     float64
#  8   Total                                    25 non-null     int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.9+ KB

# %%
df.describe()
# Out:
#        Agriculture  Construction  Trade Hotels & Restaurants  \
# count    24.000000     22.000000                   25.000000
# mean     68.500000      2.540909                   11.720000
# std      16.613536      2.046753                   11.186748
# min      19.200000      0.000000                    3.300000
# 25%      65.525000      0.975000                    7.200000
# 50%      70.550000      1.950000                    8.500000
# 75%      80.700000      3.825000                    9.700000
# max      87.900000      7.000000                   57.800000
#
#        Community, Social and Personal Services     Others  Total
# count                                23.000000  19.000000   25.0
# mean                                  5.795652   1.436842  100.0
# std                                   7.119658   0.916643    0.0
# min                                   0.300000   0.000000  100.0
# 25%                                   1.400000   0.900000  100.0
# ...

# %%
df.head()
# Out:
#             Category of States          States  Agriculture Manufacturing  \
# 0  Non Special Category states  Andhra Pradesh         69.0           9.7
# 1  Non Special Category states           Assam         69.3           8.4
# 2  Non Special Category states           Bihar         71.8          11.2
# 3  Non Special Category states    Chhattisgarh         87.9           2.4
# 4  Non Special Category states           Delhi          NaN          11.1
#
#    Construction  Trade Hotels & Restaurants  \
# 0           3.2                         9.0
# 1           1.8                         7.8
# 2           0.0                        15.5
# 3           0.9                         7.2
# 4           NaN                        57.8
#
#    Community, Social and Personal Services  Others  Total
# 0                                      7.1     2.0    100
# 1                                     11.0     1.8    100
# 2                                      1.1     0.5    100
# ...

# %%
df.tail()
# Out:
#               Category of States          States  Agriculture Manufacturing  \
# 20       Special Category States     Uttarakhand         80.7           4.7
# 21       Special Category States     Uttarakhand         80.7           4.7
# 22                     All India       All India         68.1          16.6
# 23   Non Special Category states  Andhra Pradesh         69.0           9.7
# 24  Non Special Category states*    Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 20           5.2                         9.3
# 21           5.2                         9.3
# 22           2.0                         8.5
# 23           4.0                         8.0
# 24           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 20                                      NaN     NaN    100
# 21                                      NaN     NaN    100
# ...

# %%
df.head(1)
# Out:
#             Category of States          States  Agriculture Manufacturing  \
# 0  Non Special Category states  Andhra Pradesh         69.0           9.7
#
#    Construction  Trade Hotels & Restaurants  \
# 0           3.2                         9.0
#
#    Community, Social and Personal Services  Others  Total
# 0                                      7.1     2.0    100

# %%
df.tail(1)
# Out:
#               Category of States        States  Agriculture Manufacturing  \
# 24  Non Special Category states*  Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 24           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 24                                      1.1     0.5    100

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %%
duplicated=df[df.duplicated()]
duplicated
# Out:
#              Category of States         States  Agriculture Manufacturing  \
# 17  Non Special Category states  Uttar Pradesh         61.2          25.3
# 21      Special Category States    Uttarakhand         80.7           4.7
#
#     Construction  Trade Hotels & Restaurants  \
# 17           0.4                         9.7
# 21           5.2                         9.3
#
#     Community, Social and Personal Services  Others  Total
# 17                                      2.1     1.2    100
# 21                                      NaN     NaN    100

# %%
df['States'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# Name: States, dtype: bool

# %%
df['States'].duplicated().sum()
# Out:
# 3

# %%
duplicated_states=df[df['States'].duplicated()]
duplicated_states
# Out:
#              Category of States          States  Agriculture Manufacturing  \
# 17  Non Special Category states   Uttar Pradesh         61.2          25.3
# 21      Special Category States     Uttarakhand         80.7           4.7
# 23  Non Special Category states  Andhra Pradesh         69.0           9.7
#
#     Construction  Trade Hotels & Restaurants  \
# 17           0.4                         9.7
# 21           5.2                         9.3
# 23           4.0                         8.0
#
#     Community, Social and Personal Services  Others  Total
# 17                                      2.1     1.2    100
# 21                                      NaN     NaN    100
# 23                                      7.1     2.0    100

# %%
df.drop_duplicates()
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df['States'].drop_duplicates()
# Out:
# 0       Andhra Pradesh
# 1                Assam
# 2                Bihar
# 3         Chhattisgarh
# 4                Delhi
# 5              Gujarat
# 6              Haryana
# 7            Jharkhand
# 8            Karnataka
# 9               Kerala
# 10      Madhya Pradesh
# 11         Maharashtra
# 12              Orissa
# 13              Punjab
# 14           Rajasthan
# 15          Tamil Nadu
# 16       Uttar Pradesh
# 18         West Bengal
# 19    Himachal Pradesh
# 20         Uttarakhand
# 22           All India
# 24        Biha      r*
# Name: States, dtype: object

# %%
a=df['States'].drop_duplicates()
a
# Out:
# 0       Andhra Pradesh
# 1                Assam
# 2                Bihar
# 3         Chhattisgarh
# 4                Delhi
# 5              Gujarat
# 6              Haryana
# 7            Jharkhand
# 8            Karnataka
# 9               Kerala
# 10      Madhya Pradesh
# 11         Maharashtra
# 12              Orissa
# 13              Punjab
# 14           Rajasthan
# 15          Tamil Nadu
# 16       Uttar Pradesh
# 18         West Bengal
# 19    Himachal Pradesh
# 20         Uttarakhand
# 22           All India
# 24        Biha      r*
# Name: States, dtype: object

# %%
df['States']
# Out:
# 0       Andhra Pradesh
# 1                Assam
# 2                Bihar
# 3         Chhattisgarh
# 4                Delhi
# 5              Gujarat
# 6              Haryana
# 7            Jharkhand
# 8            Karnataka
# 9               Kerala
# 10      Madhya Pradesh
# 11         Maharashtra
# 12              Orissa
# 13              Punjab
# 14           Rajasthan
# 15          Tamil Nadu
# 16       Uttar Pradesh
# 17       Uttar Pradesh
# 18         West Bengal
# 19    Himachal Pradesh
# 20         Uttarakhand
# 21         Uttarakhand
# 22           All India
# 23      Andhra Pradesh
# 24        Biha      r*
# Name: States, dtype: object

# %%
df.drop_duplicates(subset=['Category of States'])
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 19       Special Category States  Himachal Pradesh         87.4           NaN
# 22                     All India         All India         68.1          16.6
# 24  Non Special Category states*      Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 19           NaN                         6.7
# 22           2.0                         8.5
# 24           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0    100
# 19                                      4.7     1.2    100
# 22                                      3.4     1.5    100
# 24                                      1.1     0.5    100

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.drop_duplicates(subset=['Category of States'],inplace=True)

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 19       Special Category States  Himachal Pradesh         87.4           NaN
# 22                     All India         All India         68.1          16.6
# 24  Non Special Category states*      Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 19           NaN                         6.7
# 22           2.0                         8.5
# 24           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0    100
# 19                                      4.7     1.2    100
# 22                                      3.4     1.5    100
# 24                                      1.1     0.5    100

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 19       Special Category States  Himachal Pradesh         87.4           NaN
# 22                     All India         All India         68.1          16.6
# 24  Non Special Category states*      Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 19           NaN                         6.7
# 22           2.0                         8.5
# 24           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0    100
# 19                                      4.7     1.2    100
# 22                                      3.4     1.5    100
# 24                                      1.1     0.5    100

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df1=df.copy()
df1
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.isnull()
# Out:
#     Category of States  States  Agriculture  Manufacturing  Construction  \
# 0                False   False        False          False         False
# 1                False   False        False          False         False
# 2                False   False        False          False         False
# 3                False   False        False          False         False
# 4                False   False         True          False          True
# 5                False   False        False          False         False
# 6                False   False        False          False         False
# 7                False   False        False          False         False
# 8                False   False        False          False         False
# 9                False   False        False          False          True
# 10               False   False        False          False         False
# 11               False   False        False          False         False
# ...

# %%
df.isnull().sum()
# Out:
# Category of States                         0
# States                                     0
# Agriculture                                1
# Manufacturing                              1
# Construction                               3
# Trade Hotels & Restaurants                 0
# Community, Social and Personal Services    2
# Others                                     6
# Total                                      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 13

# %%
df_null=pd.read_csv(r'C:\Users\Admin\Desktop\CMRIT\DW&DV\Third_Program\Child Labour in India null.csv')
df_null
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df_null.isnull().sum().sum()
# Out:
# 22

# %%
df_null.fillna(1)
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          1.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df_null.isnull().sum().sum()
# Out:
# 22

# %%
df_null
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df2=df_null.fillna(1)

# %%
df2
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          1.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df_null
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df_null.fillna({'Agriculture':0,'Construction':1})
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df_null.isnull().sum()
# Out:
# Category of States                         1
# States                                     1
# Agriculture                                2
# Manufacturing                              2
# Construction                               4
# Trade Hotels & Restaurants                 1
# Community, Social and Personal Services    3
# Others                                     7
# Total                                      1
# dtype: int64

# %%
df_null_update=df_null.fillna({'Agriculture':0,'Construction':1})
df_null_update
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df_null_update.isnull().sum()
# Out:
# Category of States                         1
# States                                     1
# Agriculture                                0
# Manufacturing                              2
# Construction                               0
# Trade Hotels & Restaurants                 1
# Community, Social and Personal Services    3
# Others                                     7
# Total                                      1
# dtype: int64

# %%
df_null
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df_null.fillna({'Agriculture':0,'Construction':1},inplace=True)

# %%
df_null
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df_null.isnull().sum()
# Out:
# Category of States                         1
# States                                     1
# Agriculture                                0
# Manufacturing                              2
# Construction                               0
# Trade Hotels & Restaurants                 1
# Community, Social and Personal Services    3
# Others                                     7
# Total                                      1
# dtype: int64

# %%
df_null.dropna(how='any')
# Out:
#               Category of States          States  Agriculture Manufacturing  \
# 0    Non Special Category states  Andhra Pradesh         69.0           9.7
# 1    Non Special Category states           Assam         69.3           8.4
# 2    Non Special Category states           Bihar         71.8          11.2
# 5    Non Special Category states         Gujarat         76.7           2.6
# 7    Non Special Category states       Jharkhand         65.3          14.6
# 8    Non Special Category states       Karnataka         82.6           9.3
# 10   Non Special Category states  Madhya Pradesh         82.9          9. 9
# 11   Non Special Category states     Maharashtra         82.6           5.3
# 12   Non Special Category states          Orissa         73.2          17.4
# 13   Non Special Category states          Punjab         67.9          12.7
# 14   Non Special Category states       Rajasthan         75.8           9.6
# ...

# %%
df_null.isnull().sum()
# Out:
# Category of States                         1
# States                                     1
# Agriculture                                0
# Manufacturing                              2
# Construction                               0
# Trade Hotels & Restaurants                 1
# Community, Social and Personal Services    3
# Others                                     7
# Total                                      1
# dtype: int64

# %%
df_null_delete=df_null.dropna(how='any')
df_null_delete
# Out:
#               Category of States          States  Agriculture Manufacturing  \
# 0    Non Special Category states  Andhra Pradesh         69.0           9.7
# 1    Non Special Category states           Assam         69.3           8.4
# 2    Non Special Category states           Bihar         71.8          11.2
# 5    Non Special Category states         Gujarat         76.7           2.6
# 7    Non Special Category states       Jharkhand         65.3          14.6
# 8    Non Special Category states       Karnataka         82.6           9.3
# 10   Non Special Category states  Madhya Pradesh         82.9          9. 9
# 11   Non Special Category states     Maharashtra         82.6           5.3
# 12   Non Special Category states          Orissa         73.2          17.4
# 13   Non Special Category states          Punjab         67.9          12.7
# 14   Non Special Category states       Rajasthan         75.8           9.6
# ...

# %%
df_null_delete.isnull().sum()
# Out:
# Category of States                         0
# States                                     0
# Agriculture                                0
# Manufacturing                              0
# Construction                               0
# Trade Hotels & Restaurants                 0
# Community, Social and Personal Services    0
# Others                                     0
# Total                                      0
# dtype: int64

# %%
df_sp=pd.read_csv(r'C:\Users\Admin\Desktop\CMRIT\DW&DV\Third_Program\Child Labour in India special.csv')

# %%
df_sp
# Out:
#               Category of States            States Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh          69           9.7
# 1    Non Special Category states             Assam        69.3           8.4
# 2    Non Special Category states             Bihar        71.8          11.2
# 3    Non Special Category states      Chhattisgarh        87.9           2.4
# 4    Non Special Category states             Delhi         NaN          11.1
# 5    Non Special Category states           Gujarat        76.7           2.6
# 6    Non Special Category states           Haryana        65.6           3.8
# 7    Non Special Category states         Jharkhand        65.3          14.6
# 8    Non Special Category states         Karnataka        82.6           9.3
# 9    Non Special Category states            Kerala        19.2          32.8
# 10   Non Special Category states    Madhya Pradesh        82.9          9. 9
# ...

# %%
df_sp['Category of States']
# Out:
# 0      Non Special Category states
# 1      Non Special Category states
# 2      Non Special Category states
# 3      Non Special Category states
# 4      Non Special Category states
# 5      Non Special Category states
# 6      Non Special Category states
# 7      Non Special Category states
# 8      Non Special Category states
# 9      Non Special Category states
# 10     Non Special Category states
# 11     Non Special Category states
# 12     Non Special Category states
# 13     Non Special Category states
# 14     Non Special Category states
# 15     Non Special Category states
# 16     Non Special Category states
# 17     Non Special Category states
# 18     Non Special Category states
# 19         Special Category States
# 20         Special Category States
# 21                              \n
# 22         Special Category States
# 23                             NaN
# 24                       All India
# 25     Non Special Category states
# 26    Non Special Category states*
# ...

# %%
category_of_states=df_sp['Category of States'].replace(r'\W','',regex=True)
category_of_states
# Out:
# 0     NonSpecialCategorystates
# 1     NonSpecialCategorystates
# 2     NonSpecialCategorystates
# 3     NonSpecialCategorystates
# 4     NonSpecialCategorystates
# 5     NonSpecialCategorystates
# 6     NonSpecialCategorystates
# 7     NonSpecialCategorystates
# 8     NonSpecialCategorystates
# 9     NonSpecialCategorystates
# 10    NonSpecialCategorystates
# 11    NonSpecialCategorystates
# 12    NonSpecialCategorystates
# 13    NonSpecialCategorystates
# 14    NonSpecialCategorystates
# 15    NonSpecialCategorystates
# 16    NonSpecialCategorystates
# 17    NonSpecialCategorystates
# 18    NonSpecialCategorystates
# 19       SpecialCategoryStates
# 20       SpecialCategoryStates
# 21                           n
# 22       SpecialCategoryStates
# 23                         NaN
# 24                    AllIndia
# 25    NonSpecialCategorystates
# 26    NonSpecialCategorystates
# 27
# 28
# 29                           n
# Name: Category of States, dtype: object

# %%
df_sp['States']
# Out:
# 0       Andhra Pradesh
# 1                Assam
# 2                Bihar
# 3         Chhattisgarh
# 4                Delhi
# 5              Gujarat
# 6              Haryana
# 7            Jharkhand
# 8            Karnataka
# 9               Kerala
# 10      Madhya Pradesh
# 11         Maharashtra
# 12              Orissa
# 13              Punjab
# 14           Rajasthan
# 15          Tamil Nadu
# 16       Uttar Pradesh
# 17       Uttar Pradesh
# 18         West Bengal
# 19    Himachal Pradesh
# 20         Uttarakhand
# 21                  \n
# 22         Uttarakhand
# 23                 NaN
# 24           All India
# 25      Andhra Pradesh
# 26        Biha      r*
# 27                  ""
# 28                 " "
# 29                "\n"
# Name: States, dtype: object

# %%
states=df_sp['States'].replace(r'\W','',regex=True)
states
# Out:
# 0       AndhraPradesh
# 1               Assam
# 2               Bihar
# 3        Chhattisgarh
# 4               Delhi
# 5             Gujarat
# 6             Haryana
# 7           Jharkhand
# 8           Karnataka
# 9              Kerala
# 10      MadhyaPradesh
# 11        Maharashtra
# 12             Orissa
# 13             Punjab
# 14          Rajasthan
# 15          TamilNadu
# 16       UttarPradesh
# 17       UttarPradesh
# 18         WestBengal
# 19    HimachalPradesh
# 20        Uttarakhand
# 21                  n
# 22        Uttarakhand
# 23                NaN
# 24           AllIndia
# 25      AndhraPradesh
# 26              Bihar
# 27
# 28
# 29                  n
# Name: States, dtype: object

# %%
states=[states for states in df['States'] if states.strip()]

# %%
states
# Out:
# ['Andhra Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Delhi',
#  'Gujarat',
#  'Haryana',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Orissa',
#  'Punjab',
#  'Rajasthan',
#  'Tamil Nadu',
#  'Uttar Pradesh',
#  'Uttar Pradesh',
#  'West Bengal',
#  'Himachal Pradesh',
#  'Uttarakhand',
#  'Uttarakhand',
#  'All India',
#  'Andhra Pradesh',
#  'Biha      r*']

# %%
print('The total no of rows {}''\n''The total no of columns {}'.format(df.shape[0],df.shape[1]))
# Out:
# The total no of rows 25
# The total no of columns 9

# %%
df.drop('Category of States',axis=1)
# Out:
#               States  Agriculture Manufacturing  Construction  \
# 0     Andhra Pradesh         69.0           9.7           3.2
# 1              Assam         69.3           8.4           1.8
# 2              Bihar         71.8          11.2           0.0
# 3       Chhattisgarh         87.9           2.4           0.9
# 4              Delhi          NaN          11.1           NaN
# 5            Gujarat         76.7           2.6           0.3
# 6            Haryana         65.6           3.8           7.0
# 7          Jharkhand         65.3          14.6           4.3
# 8          Karnataka         82.6           9.3           1.2
# 9             Kerala         19.2          32.8           NaN
# 10    Madhya Pradesh         82.9          9. 9           1.5
# 11       Maharashtra         82.6           5.3           1.9
# 12            Orissa         73.2          17.4           3.3
# 13            Punjab         67.9          12.7           1.2
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.drop('Category of States',axis=1,inplace=True)

# %%
df
# Out:
#               States  Agriculture Manufacturing  Construction  \
# 0     Andhra Pradesh         69.0           9.7           3.2
# 1              Assam         69.3           8.4           1.8
# 2              Bihar         71.8          11.2           0.0
# 3       Chhattisgarh         87.9           2.4           0.9
# 4              Delhi          NaN          11.1           NaN
# 5            Gujarat         76.7           2.6           0.3
# 6            Haryana         65.6           3.8           7.0
# 7          Jharkhand         65.3          14.6           4.3
# 8          Karnataka         82.6           9.3           1.2
# 9             Kerala         19.2          32.8           NaN
# 10    Madhya Pradesh         82.9          9. 9           1.5
# 11       Maharashtra         82.6           5.3           1.9
# 12            Orissa         73.2          17.4           3.3
# 13            Punjab         67.9          12.7           1.2
# ...

# %%
df.drop(1,axis=0)
# Out:
#               States  Agriculture Manufacturing  Construction  \
# 0     Andhra Pradesh         69.0           9.7           3.2
# 2              Bihar         71.8          11.2           0.0
# 3       Chhattisgarh         87.9           2.4           0.9
# 4              Delhi          NaN          11.1           NaN
# 5            Gujarat         76.7           2.6           0.3
# 6            Haryana         65.6           3.8           7.0
# 7          Jharkhand         65.3          14.6           4.3
# 8          Karnataka         82.6           9.3           1.2
# 9             Kerala         19.2          32.8           NaN
# 10    Madhya Pradesh         82.9          9. 9           1.5
# 11       Maharashtra         82.6           5.3           1.9
# 12            Orissa         73.2          17.4           3.3
# 13            Punjab         67.9          12.7           1.2
# 14         Rajasthan         75.8           9.6           2.9
# ...

# %%
df
# Out:
#               States  Agriculture Manufacturing  Construction  \
# 0     Andhra Pradesh         69.0           9.7           3.2
# 1              Assam         69.3           8.4           1.8
# 2              Bihar         71.8          11.2           0.0
# 3       Chhattisgarh         87.9           2.4           0.9
# 4              Delhi          NaN          11.1           NaN
# 5            Gujarat         76.7           2.6           0.3
# 6            Haryana         65.6           3.8           7.0
# 7          Jharkhand         65.3          14.6           4.3
# 8          Karnataka         82.6           9.3           1.2
# 9             Kerala         19.2          32.8           NaN
# 10    Madhya Pradesh         82.9          9. 9           1.5
# 11       Maharashtra         82.6           5.3           1.9
# 12            Orissa         73.2          17.4           3.3
# 13            Punjab         67.9          12.7           1.2
# ...

# %%
df.drop(1,axis=0,inplace=True)

# %%
df
# Out:
#               States  Agriculture Manufacturing  Construction  \
# 0     Andhra Pradesh         69.0           9.7           3.2
# 2              Bihar         71.8          11.2           0.0
# 3       Chhattisgarh         87.9           2.4           0.9
# 4              Delhi          NaN          11.1           NaN
# 5            Gujarat         76.7           2.6           0.3
# 6            Haryana         65.6           3.8           7.0
# 7          Jharkhand         65.3          14.6           4.3
# 8          Karnataka         82.6           9.3           1.2
# 9             Kerala         19.2          32.8           NaN
# 10    Madhya Pradesh         82.9          9. 9           1.5
# 11       Maharashtra         82.6           5.3           1.9
# 12            Orissa         73.2          17.4           3.3
# 13            Punjab         67.9          12.7           1.2
# 14         Rajasthan         75.8           9.6           2.9
# ...

# %%
rename_col=['Category' if 'Category of States' in colname else
            'Agri' if 'Agricultue' in colname else colname for colname in df
           ]

# %%
rename_col
# Out:
# ['Category',
#  'States',
#  'Agriculture',
#  'Manufacturing',
#  'Construction',
#  'Trade Hotels & Restaurants',
#  'Community, Social and Personal Services',
#  'Others',
#  'Total']

# %%
states_match=df['States']=='Andhra Pradesh'
states_match
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# Name: States, dtype: bool

# %%
states_match=df[df['States']=='Andhra Pradesh']
states_match
# Out:
#              Category of States          States  Agriculture Manufacturing  \
# 0   Non Special Category states  Andhra Pradesh         69.0           9.7
# 23  Non Special Category states  Andhra Pradesh         69.0           9.7
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 23           4.0                         8.0
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0    100
# 23                                      7.1     2.0    100

# %%
states_not_match=df[df['States']!='Andhra Pradesh']
states_not_match
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          NaN          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# 11   Non Special Category states       Maharashtra         82.6           5.3
# ...

# %%
df['States'].value_counts()
# Out:
# Andhra Pradesh      2
# Uttarakhand         2
# Uttar Pradesh       2
# Assam               1
# All India           1
# Himachal Pradesh    1
# West Bengal         1
# Tamil Nadu          1
# Rajasthan           1
# Punjab              1
# Orissa              1
# Maharashtra         1
# Madhya Pradesh      1
# Kerala              1
# Karnataka           1
# Jharkhand           1
# Haryana             1
# Gujarat             1
# Delhi               1
# Chhattisgarh        1
# Bihar               1
# Biha      r*        1
# Name: States, dtype: int64

# %%
df['States'].value_counts().plot()
# Out:
# <Axes: >

# %%
df['States'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['States'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi',
#        'Gujarat', 'Haryana', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Orissa', 'Punjab', 'Rajasthan',
#        'Tamil Nadu', 'Uttar Pradesh', 'West Bengal', 'Himachal Pradesh',
#        'Uttarakhand', 'All India', 'Biha      r*'], dtype=object)

# %%
df['States'].nunique()
# Out:
# 22

# %%
df.dtypes
# Out:
# Category of States                          object
# States                                      object
# Agriculture                                float64
# Manufacturing                               object
# Construction                               float64
# Trade Hotels & Restaurants                 float64
# Community, Social and Personal Services    float64
# Others                                     float64
# Total                                        int64
# dtype: object

# %%
df['Manufacturing'] =df['Manufacturing'].replace('9. 9', '9.9')
df['Manufacturing'] = df['Manufacturing'].astype('float')
df['Manufacturing']
df.dtypes
# Out:
# Category of States                          object
# States                                      object
# Agriculture                                float64
# Manufacturing                              float64
# Construction                               float64
# Trade Hotels & Restaurants                 float64
# Community, Social and Personal Services    float64
# Others                                     float64
# Total                                        int64
# dtype: object
